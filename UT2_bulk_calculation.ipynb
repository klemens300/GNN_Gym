# %%
"""
Bulk NEB Calculation Script

Generate multiple NEB calculations with customizable parameters.
Useful for generating large datasets for training.
"""

from config import Config
from oracle import Oracle
import numpy as np
from datetime import datetime


# ============================================================================
# BULK CALCULATION PARAMETERS - ADJUST HERE
# ============================================================================

# Number of samples to generate
N_SAMPLES = 10000

# Random seed for reproducibility
SEED = 42

# Elements to use (override config if needed, or set to None to use config)
ELEMENTS = ['Mo', 'Nb', 'Ta', 'W', 'O']  # e.g., ['Mo', 'Nb', 'Ta', 'W'] or None

# Number of runs per composition
RUNS_PER_COMPOSITION = 1

# ============================================================================


def sample_random_compositions(n_samples, elements, seed=None):
    """
    Sample random compositions using Dirichlet distribution.
    
    The Dirichlet distribution ensures compositions sum to 1.
    
    Parameters:
    -----------
    n_samples : int
        Number of compositions to generate
    elements : list of str
        Element symbols
    seed : int, optional
        Random seed for reproducibility
    
    Returns:
    --------
    compositions : list of dict
        Each dict maps element symbol to concentration
    """
    if seed is not None:
        np.random.seed(seed)
    
    n_elements = len(elements)
    compositions = []
    
    for _ in range(n_samples):
        # Sample from Dirichlet distribution (uniform over simplex)
        fractions = np.random.dirichlet([1.0] * n_elements)
        
        comp = {elem: float(frac) for elem, frac in zip(elements, fractions)}
        compositions.append(comp)
    
    return compositions


def print_bulk_config(config):
    """Print bulk calculation configuration"""
    print("\n" + "="*70)
    print("BULK CALCULATION CONFIGURATION")
    print("="*70)
    
    elements = ELEMENTS if ELEMENTS else config.elements
    
    print("\nBulk Parameters:")
    print(f"  Number of samples:        {N_SAMPLES}")
    print(f"  Runs per composition:     {RUNS_PER_COMPOSITION}")
    print(f"  Total calculations:       {N_SAMPLES * RUNS_PER_COMPOSITION}")
    print(f"  Random seed:              {SEED}")
    print(f"  Elements:                 {', '.join(elements)}")
    
    print("\nOracle Configuration:")
    print(f"  Calculator:               CHGNet")
    print(f"  Supercell size:           {config.supercell_size}x{config.supercell_size}x{config.supercell_size}")
    print(f"  Lattice parameter:        {config.lattice_parameter} Å")
    print(f"  NEB images:               {config.neb_images}")
    print(f"  NEB max steps:            {config.neb_max_steps}")
    print(f"  NEB fmax:                 {config.neb_fmax} eV/Å")
    print(f"  Relax max steps:          {config.relax_max_steps}")
    print(f"  Relax fmax:               {config.relax_fmax} eV/Å")
    
    print("\nData Storage:")
    print(f"  Database directory:       {config.database_dir}")
    print(f"  CSV path:                 {config.csv_path}")
    
    print("="*70)


def run_bulk_calculation():
    """Run bulk NEB calculations"""
    
    # Load config
    config = Config()
    
    # Determine elements
    elements = ELEMENTS if ELEMENTS else config.elements
    
    # Print configuration
    print_bulk_config(config)
    
    print("\nStarting bulk calculation...")
    print(f"Start time: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
    
    input("Press ENTER to start (or Ctrl+C to cancel)...")
    
    # Sample compositions
    print(f"\nSampling {N_SAMPLES} random compositions...")
    compositions = sample_random_compositions(
        n_samples=N_SAMPLES,
        elements=elements,
        seed=SEED
    )
    print(f"✓ Sampled {len(compositions)} compositions")
    
    # Show first few compositions
    print("\nFirst 5 compositions:")
    for i, comp in enumerate(compositions[:5]):
        comp_str = ", ".join([f"{k}={v:.2f}" for k, v in comp.items()])
        print(f"  {i+1}. {comp_str}")
    if len(compositions) > 5:
        print(f"  ... and {len(compositions) - 5} more")
    
    # Run calculations
    print(f"\n{'='*70}")
    print("STARTING CALCULATIONS")
    print(f"{'='*70}\n")
    
    total_calculations = len(compositions) * RUNS_PER_COMPOSITION
    completed = 0
    failed = 0
    
    with Oracle(config) as oracle:
        for i, comp in enumerate(compositions, 1):
            print(f"\nComposition {i}/{len(compositions)}:")
            
            for run in range(RUNS_PER_COMPOSITION):
                if RUNS_PER_COMPOSITION > 1:
                    print(f"  Run {run+1}/{RUNS_PER_COMPOSITION}:")
                
                success = oracle.calculate(comp)
                
                if success:
                    completed += 1
                else:
                    failed += 1
                
                # Progress update
                progress = (completed + failed) / total_calculations * 100
                print(f"  Progress: {completed + failed}/{total_calculations} ({progress:.1f}%) | "
                      f"Completed: {completed} | Failed: {failed}")
    
    # Final summary
    print(f"\n{'='*70}")
    print("BULK CALCULATION COMPLETE")
    print(f"{'='*70}")
    print(f"\nEnd time: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    print(f"\nResults:")
    print(f"  Total calculations:  {total_calculations}")
    print(f"  Completed:           {completed} ({completed/total_calculations*100:.1f}%)")
    print(f"  Failed:              {failed} ({failed/total_calculations*100:.1f}%)")
    print(f"\nData saved to:")
    print(f"  Database: {config.database_dir}")
    print(f"  CSV:      {config.csv_path}")
    print(f"\n{'='*70}\n")


if __name__ == "__main__":
    run_bulk_calculation()
# Out:
# ======================================================================
# BULK CALCULATION CONFIGURATION
# ======================================================================
#
# Bulk Parameters:
#   Number of samples:        10000
#   Runs per composition:     1
#   Total calculations:       10000
#   Random seed:              42
#   Elements:                 Mo, Nb, Ta, W, O
#
# Oracle Configuration:
#   Calculator:               CHGNet
#   Supercell size:           4x4x4
#   Lattice parameter:        3.2 Å
#   NEB images:               5
#   NEB max steps:            200
#   NEB fmax:                 0.05 eV/Å
#   Relax max steps:          500
#   Relax fmax:               0.05 eV/Å
#
# Data Storage:
#   Database directory:       database
#   CSV path:                 database_navi.csv
# ======================================================================
#
# Starting bulk calculation...
# Start time: 2025-10-27 01:37:00
#
#
# Sampling 10000 random compositions...
# ✓ Sampled 10000 compositions
#
# First 5 compositions:
#   1. Mo=0.08, Nb=0.51, Ta=0.22, W=0.16, O=0.03
#   2. Mo=0.04, Nb=0.01, Ta=0.46, W=0.21, O=0.28
#   3. Mo=0.00, Nb=0.61, Ta=0.31, W=0.04, O=0.03
#   4. Mo=0.09, Nb=0.16, Ta=0.34, W=0.25, O=0.16
#   5. Mo=0.38, Nb=0.06, Ta=0.14, W=0.18, O=0.24
#   ... and 9995 more
#
# ======================================================================
# STARTING CALCULATIONS
# ======================================================================
#
# Oracle initialized
#   Database: database
#   CSV: database_navi.csv
#
# Composition 1/10000:
#
# Calculating Mo8Nb51O3Ta22W16 (run 2)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 48.2s
#   Diffusing element: O
#   Forward barrier: 11.474 eV
#   Backward barrier: 12.063 eV
#   Timing: relax=9.1s, neb=38.3s
#   Progress: 1/10000 (0.0%) | Completed: 1 | Failed: 0
#
# Composition 2/10000:
#
# Calculating Mo4Nb1O28Ta46W21 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 75.2s
#   Diffusing element: O
#   Forward barrier: 131.708 eV
#   Backward barrier: 129.999 eV
#   Timing: relax=47.2s, neb=27.7s
#   Progress: 2/10000 (0.0%) | Completed: 2 | Failed: 0
#
# Composition 3/10000:
#
# Calculating Mo0Nb61O3Ta31W4 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 45.5s
#   Diffusing element: Ta
#   Forward barrier: 1.745 eV
#   Backward barrier: 0.903 eV
#   Timing: relax=6.7s, neb=38.5s
#   Progress: 3/10000 (0.0%) | Completed: 3 | Failed: 0
#
# Composition 4/10000:
#
# Calculating Mo9Nb16O16Ta34W25 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 62.6s
#   Diffusing element: Ta
#   Forward barrier: 15.241 eV
#   Backward barrier: 11.235 eV
#   Timing: relax=26.2s, neb=36.1s
#   Progress: 4/10000 (0.0%) | Completed: 4 | Failed: 0
#
# Composition 5/10000:
#
# Calculating Mo38Nb6O24Ta14W18 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 64.4s
#   Diffusing element: W
#   Forward barrier: 81.500 eV
#   Backward barrier: 85.877 eV
#   Timing: relax=32.4s, neb=31.7s
#   Progress: 5/10000 (0.1%) | Completed: 5 | Failed: 0
#
# Composition 6/10000:
#
# Calculating Mo45Nb6O1Ta21W26 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 10.9s
#   Diffusing element: W
#   Forward barrier: 0.689 eV
#   Backward barrier: 0.967 eV
#   Timing: relax=5.9s, neb=4.7s
#   Progress: 6/10000 (0.1%) | Completed: 6 | Failed: 0
#
# Composition 7/10000:
#
# Calculating Mo12Nb2O45Ta1W39 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 72.3s
#   Diffusing element: W
#   Forward barrier: 116.203 eV
#   Backward barrier: 122.858 eV
#   Timing: relax=39.1s, neb=32.9s
#   Progress: 7/10000 (0.1%) | Completed: 7 | Failed: 0
#
# Composition 8/10000:
#
# Calculating Mo43Nb9O15Ta3W30 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 56.4s
#   Diffusing element: O
#   Forward barrier: 7.278 eV
#   Backward barrier: 7.790 eV
#   Timing: relax=20.8s, neb=35.3s
#   Progress: 8/10000 (0.1%) | Completed: 8 | Failed: 0
#
# Composition 9/10000:
#
# Calculating Mo4Nb19O8Ta1W68 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 28.5s
#   Diffusing element: W
#   Forward barrier: 0.843 eV
#   Backward barrier: 1.505 eV
#   Timing: relax=15.7s, neb=12.5s
#   Progress: 9/10000 (0.1%) | Completed: 9 | Failed: 0
#
# Composition 10/10000:
#
# Calculating Mo34Nb12O6Ta23W25 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 16.9s
#   Diffusing element: Mo
#   Forward barrier: 0.000 eV
#   Backward barrier: 0.519 eV
#   Timing: relax=9.5s, neb=7.1s
#   Progress: 10/10000 (0.1%) | Completed: 10 | Failed: 0
#
# Composition 11/10000:
#
# Calculating Mo32Nb14O8Ta26W21 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 25.3s
#   Diffusing element: Ta
#   Forward barrier: 0.494 eV
#   Backward barrier: 1.439 eV
#   Timing: relax=11.1s, neb=13.7s
#   Progress: 11/10000 (0.1%) | Completed: 11 | Failed: 0
#
# Composition 12/10000:
#
# Calculating Mo77Nb3O12Ta7W1 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 53.6s
#   Diffusing element: Mo
#   Forward barrier: 7.954 eV
#   Backward barrier: 10.197 eV
#   Timing: relax=19.7s, neb=33.5s
#   Progress: 12/10000 (0.1%) | Completed: 12 | Failed: 0
#
# Composition 13/10000:
#
# Calculating Mo15Nb9O10Ta53W13 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 44.6s
#   Diffusing element: Ta
#   Forward barrier: 11.655 eV
#   Backward barrier: 10.349 eV
#   Timing: relax=9.6s, neb=34.7s
#   Progress: 13/10000 (0.1%) | Completed: 13 | Failed: 0
#
# Composition 14/10000:
#
# Calculating Mo11Nb2O62Ta23W1 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 70.3s
#   Diffusing element: Ta
#   Forward barrier: 22.830 eV
#   Backward barrier: 21.513 eV
#   Timing: relax=40.4s, neb=29.6s
#   Progress: 14/10000 (0.1%) | Completed: 14 | Failed: 0
#
# Composition 15/10000:
#
# Calculating Mo32Nb5O27Ta0W37 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 94.5s
#   Diffusing element: Mo
#   Forward barrier: 94.050 eV
#   Backward barrier: 88.931 eV
#   Timing: relax=52.6s, neb=41.4s
#   Progress: 15/10000 (0.1%) | Completed: 15 | Failed: 0
#
# Composition 16/10000:
#
# Calculating Mo38Nb43O4Ta2W13 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 31.0s
#   Diffusing element: Nb
#   Forward barrier: 0.534 eV
#   Backward barrier: 1.039 eV
#   Timing: relax=10.6s, neb=19.9s
#   Progress: 16/10000 (0.2%) | Completed: 16 | Failed: 0
#
# Composition 17/10000:
#
# Calculating Mo52Nb26O10Ta11W2 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 50.6s
#   Diffusing element: Nb
#   Forward barrier: 16.283 eV
#   Backward barrier: 15.473 eV
#   Timing: relax=12.7s, neb=37.6s
#   Progress: 17/10000 (0.2%) | Completed: 17 | Failed: 0
#
# Composition 18/10000:
#
# Calculating Mo7Nb24O12Ta18W39 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 53.4s
#   Diffusing element: O
#   Forward barrier: 12.067 eV
#   Backward barrier: 13.556 eV
#   Timing: relax=18.2s, neb=34.9s
#   Progress: 18/10000 (0.2%) | Completed: 18 | Failed: 0
#
# Composition 19/10000:
#
# Calculating Mo2Nb24O29Ta28W16 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 82.6s
#   Diffusing element: O
#   Forward barrier: 72.178 eV
#   Backward barrier: 73.619 eV
#   Timing: relax=43.9s, neb=38.2s
#   Progress: 19/10000 (0.2%) | Completed: 19 | Failed: 0
#
# Composition 20/10000:
#
# Calculating Mo32Nb35O5Ta26W1 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 23.7s
#   Diffusing element: Ta
#   Forward barrier: 0.915 eV
#   Backward barrier: 1.092 eV
#   Timing: relax=11.6s, neb=11.8s
#   Progress: 20/10000 (0.2%) | Completed: 20 | Failed: 0
#
# Composition 21/10000:
#
# Calculating Mo1Nb22O53Ta8W16 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 81.6s
#   Diffusing element: O
#   Forward barrier: 48.287 eV
#   Backward barrier: 51.356 eV
#   Timing: relax=45.0s, neb=36.2s
#   Progress: 21/10000 (0.2%) | Completed: 21 | Failed: 0
#
# Composition 22/10000:
#
# Calculating Mo11Nb21O3Ta55W10 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 45.1s
#   Diffusing element: Ta
#   Forward barrier: 18.849 eV
#   Backward barrier: 18.190 eV
#   Timing: relax=6.6s, neb=38.1s
#   Progress: 22/10000 (0.2%) | Completed: 22 | Failed: 0
#
# Composition 23/10000:
#
# Calculating Mo6Nb3O17Ta46W28 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 78.3s
#   Diffusing element: W
#   Forward barrier: 59.546 eV
#   Backward barrier: 47.422 eV
#   Timing: relax=43.4s, neb=34.5s
#   Progress: 23/10000 (0.2%) | Completed: 23 | Failed: 0
#
# Composition 24/10000:
#
# Calculating Mo30Nb24O11Ta3W32 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 61.9s
#   Diffusing element: W
#   Forward barrier: 0.719 eV
#   Backward barrier: 3.332 eV
#   Timing: relax=22.1s, neb=39.4s
#   Progress: 24/10000 (0.2%) | Completed: 24 | Failed: 0
#
# Composition 25/10000:
#
# Calculating Mo35Nb48O6Ta8W2 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 46.6s
#   Diffusing element: Mo
#   Forward barrier: 17.364 eV
#   Backward barrier: 21.284 eV
#   Timing: relax=9.2s, neb=37.1s
#   Progress: 25/10000 (0.2%) | Completed: 25 | Failed: 0
#
# Composition 26/10000:
#
# Calculating Mo11Nb34O14Ta40W0 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 74.8s
#   Diffusing element: Mo
#   Forward barrier: 2.196 eV
#   Backward barrier: 0.633 eV
#   Timing: relax=38.6s, neb=35.9s
#   Progress: 26/10000 (0.3%) | Completed: 26 | Failed: 0
#
# Composition 27/10000:
#
# Calculating Mo13Nb6O68Ta3W10 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 87.6s
#   Diffusing element: W
#   Forward barrier: 27.506 eV
#   Backward barrier: 31.184 eV
#   Timing: relax=56.4s, neb=30.8s
#   Progress: 27/10000 (0.3%) | Completed: 27 | Failed: 0
#
# Composition 28/10000:
#
# Calculating Mo6Nb12O56Ta19W7 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 72.8s
#   Diffusing element: O
#   Forward barrier: 27.940 eV
#   Backward barrier: 31.325 eV
#   Timing: relax=39.2s, neb=33.3s
#   Progress: 28/10000 (0.3%) | Completed: 28 | Failed: 0
#
# Composition 29/10000:
#
# Calculating Mo66Nb6O7Ta14W7 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 22.5s
#   Diffusing element: Mo
#   Forward barrier: 0.286 eV
#   Backward barrier: 0.609 eV
#   Timing: relax=12.3s, neb=9.8s
#   Progress: 29/10000 (0.3%) | Completed: 29 | Failed: 0
#
# Composition 30/10000:
#
# Calculating Mo2Nb46O16Ta34W3 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 61.2s
#   Diffusing element: Nb
#   Forward barrier: 105.185 eV
#   Backward barrier: 101.704 eV
#   Timing: relax=26.2s, neb=34.7s
#   Progress: 30/10000 (0.3%) | Completed: 30 | Failed: 0
#
# Composition 31/10000:
#
# Calculating Mo31Nb4O55Ta2W9 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 69.4s
#   Diffusing element: W
#   Forward barrier: 61.960 eV
#   Backward barrier: 62.428 eV
#   Timing: relax=39.0s, neb=30.0s
#   Progress: 31/10000 (0.3%) | Completed: 31 | Failed: 0
#
# Composition 32/10000:
#
# Calculating Mo6Nb25O30Ta33W6 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 63.0s
#   Diffusing element: Mo
#   Forward barrier: 6.896 eV
#   Backward barrier: 8.037 eV
#   Timing: relax=31.8s, neb=30.9s
#   Progress: 32/10000 (0.3%) | Completed: 32 | Failed: 0
#
# Composition 33/10000:
#
# Calculating Mo14Nb30O3Ta30W23 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 20.2s
#   Diffusing element: W
#   Forward barrier: 1.171 eV
#   Backward barrier: 0.979 eV
#   Timing: relax=8.1s, neb=11.7s
#   Progress: 33/10000 (0.3%) | Completed: 33 | Failed: 0
#
# Composition 34/10000:
#
# Calculating Mo54Nb12O27Ta6W1 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 89.0s
#   Diffusing element: O
#   Forward barrier: 90.231 eV
#   Backward barrier: 88.526 eV
#   Timing: relax=51.8s, neb=36.8s
#   Progress: 34/10000 (0.3%) | Completed: 34 | Failed: 0
#
# Composition 35/10000:
#
# Calculating Mo36Nb1O33Ta23W8 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 102.9s
#   Diffusing element: Ta
#   Forward barrier: 29.971 eV
#   Backward barrier: 22.283 eV
#   Timing: relax=62.5s, neb=40.1s
#   Progress: 35/10000 (0.4%) | Completed: 35 | Failed: 0
#
# Composition 36/10000:
#
# Calculating Mo4Nb25O3Ta10W58 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 15.8s
#   Diffusing element: W
#   Forward barrier: 0.581 eV
#   Backward barrier: 0.688 eV
#   Timing: relax=5.3s, neb=10.1s
#   Progress: 36/10000 (0.4%) | Completed: 36 | Failed: 0
#
# Composition 37/10000:
#
# Calculating Mo8Nb2O5Ta47W38 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 24.8s
#   Diffusing element: Ta
#   Forward barrier: 1.738 eV
#   Backward barrier: 0.000 eV
#   Timing: relax=8.8s, neb=15.6s
#   Progress: 37/10000 (0.4%) | Completed: 37 | Failed: 0
#
# Composition 38/10000:
#
# Calculating Mo23Nb37O6Ta18W16 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 51.5s
#   Diffusing element: Nb
#   Forward barrier: 22.201 eV
#   Backward barrier: 22.976 eV
#   Timing: relax=11.1s, neb=40.0s
#   Progress: 38/10000 (0.4%) | Completed: 38 | Failed: 0
#
# Composition 39/10000:
#
# Calculating Mo2Nb37O7Ta38W16 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 60.0s
#   Diffusing element: W
#   Forward barrier: 27.964 eV
#   Backward barrier: 28.468 eV
#   Timing: relax=17.2s, neb=42.4s
#   Progress: 39/10000 (0.4%) | Completed: 39 | Failed: 0
#
# Composition 40/10000:
#
# Calculating Mo6Nb17O20Ta30W28 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 81.8s
#   Diffusing element: W
#   Forward barrier: 6.514 eV
#   Backward barrier: 12.223 eV
#   Timing: relax=42.9s, neb=38.6s
#   Progress: 40/10000 (0.4%) | Completed: 40 | Failed: 0
#
# Composition 41/10000:
#
# Calculating Mo23Nb2O21Ta4W51 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 89.1s
#   Diffusing element: Mo
#   Forward barrier: 103.354 eV
#   Backward barrier: 87.760 eV
#   Timing: relax=54.0s, neb=34.8s
#   Progress: 41/10000 (0.4%) | Completed: 41 | Failed: 0
#
# Composition 42/10000:
#
# Calculating Mo1Nb8O13Ta79W0 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 52.4s
#   Diffusing element: Ta
#   Forward barrier: 23.291 eV
#   Backward barrier: 18.978 eV
#   Timing: relax=19.1s, neb=33.0s
#   Progress: 42/10000 (0.4%) | Completed: 42 | Failed: 0
#
# Composition 43/10000:
#
# Calculating Mo18Nb26O28Ta23W6 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 80.2s
#   Diffusing element: Ta
#   Forward barrier: 6.031 eV
#   Backward barrier: 10.554 eV
#   Timing: relax=43.5s, neb=36.3s
#   Progress: 43/10000 (0.4%) | Completed: 43 | Failed: 0
#
# Composition 44/10000:
#
# Calculating Mo5Nb8O38Ta28W21 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 80.3s
#   Diffusing element: W
#   Forward barrier: 18.483 eV
#   Backward barrier: 16.759 eV
#   Timing: relax=50.0s, neb=29.9s
#   Progress: 44/10000 (0.4%) | Completed: 44 | Failed: 0
#
# Composition 45/10000:
#
# Calculating Mo39Nb30O11Ta4W17 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 59.7s
#   Diffusing element: Mo
#   Forward barrier: 3.199 eV
#   Backward barrier: 3.056 eV
#   Timing: relax=25.8s, neb=33.6s
#   Progress: 45/10000 (0.4%) | Completed: 45 | Failed: 0
#
# Composition 46/10000:
#
# Calculating Mo4Nb47O13Ta7W29 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 55.2s
#   Diffusing element: O
#   Forward barrier: 25.224 eV
#   Backward barrier: 22.567 eV
#   Timing: relax=20.3s, neb=34.5s
#   Progress: 46/10000 (0.5%) | Completed: 46 | Failed: 0
#
# Composition 47/10000:
#
# Calculating Mo39Nb17O5Ta21W17 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 21.9s
#   Diffusing element: Mo
#   Forward barrier: 0.600 eV
#   Backward barrier: 1.562 eV
#   Timing: relax=9.2s, neb=12.3s
#   Progress: 47/10000 (0.5%) | Completed: 47 | Failed: 0
#
# Composition 48/10000:
#
# Calculating Mo45Nb11O7Ta1W36 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 27.8s
#   Diffusing element: Mo
#   Forward barrier: 0.993 eV
#   Backward barrier: 0.512 eV
#   Timing: relax=13.3s, neb=14.2s
#   Progress: 48/10000 (0.5%) | Completed: 48 | Failed: 0
#
# Composition 49/10000:
#
# Calculating Mo32Nb35O0Ta28W5 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 9.9s
#   Diffusing element: Ta
#   Forward barrier: 0.478 eV
#   Backward barrier: 0.743 eV
#   Timing: relax=3.8s, neb=5.8s
#   Progress: 49/10000 (0.5%) | Completed: 49 | Failed: 0
#
# Composition 50/10000:
#
# Calculating Mo22Nb5O16Ta29W28 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 63.7s
#   Diffusing element: W
#   Forward barrier: 141.457 eV
#   Backward barrier: 129.808 eV
#   Timing: relax=21.5s, neb=43.2s
#   Progress: 50/10000 (0.5%) | Completed: 50 | Failed: 0
#
# Composition 51/10000:
#
# Calculating Mo11Nb15O6Ta58W12 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 60.8s
#   Diffusing element: Ta
#   Forward barrier: 9.843 eV
#   Backward barrier: 12.559 eV
#   Timing: relax=14.1s, neb=46.4s
#   Progress: 51/10000 (0.5%) | Completed: 51 | Failed: 0
#
# Composition 52/10000:
#
# Calculating Mo14Nb48O2Ta21W15 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 12.3s
#   Diffusing element: Nb
#   Forward barrier: 0.436 eV
#   Backward barrier: 0.288 eV
#   Timing: relax=6.6s, neb=5.4s
#   Progress: 52/10000 (0.5%) | Completed: 52 | Failed: 0
#
# Composition 53/10000:
#
# Calculating Mo11Nb54O25Ta2W9 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 99.0s
#   Diffusing element: Nb
#   Forward barrier: 92.562 eV
#   Backward barrier: 91.663 eV
#   Timing: relax=55.5s, neb=43.1s
#   Progress: 53/10000 (0.5%) | Completed: 53 | Failed: 0
#
# Composition 54/10000:
#
# Calculating Mo30Nb26O8Ta27W10 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 59.8s
#   Diffusing element: Nb
#   Forward barrier: 50.115 eV
#   Backward barrier: 50.766 eV
#   Timing: relax=18.3s, neb=41.1s
#   Progress: 54/10000 (0.5%) | Completed: 54 | Failed: 0
#
# Composition 55/10000:
#
# Calculating Mo20Nb20O8Ta24W29 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 30.9s
#   Diffusing element: Nb
#   Forward barrier: 0.341 eV
#   Backward barrier: 2.394 eV
#   Timing: relax=14.8s, neb=15.8s
#   Progress: 55/10000 (0.5%) | Completed: 55 | Failed: 0
#
# Composition 56/10000:
#
# Calculating Mo11Nb26O26Ta17W20 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 85.2s
#   Diffusing element: Nb
#   Forward barrier: 100.241 eV
#   Backward barrier: 100.898 eV
#   Timing: relax=52.9s, neb=32.0s
#   Progress: 56/10000 (0.6%) | Completed: 56 | Failed: 0
#
# Composition 57/10000:
#
# Calculating Mo54Nb10O21Ta12W2 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 74.2s
#   Diffusing element: Mo
#   Forward barrier: 123.001 eV
#   Backward barrier: 128.960 eV
#   Timing: relax=37.7s, neb=36.2s
#   Progress: 57/10000 (0.6%) | Completed: 57 | Failed: 0
#
# Composition 58/10000:
#
# Calculating Mo1Nb23O33Ta29W13 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 81.6s
#   Diffusing element: Nb
#   Forward barrier: 9.015 eV
#   Backward barrier: 12.527 eV
#   Timing: relax=48.0s, neb=33.2s
#   Progress: 58/10000 (0.6%) | Completed: 58 | Failed: 0
#
# Composition 59/10000:
#
# Calculating Mo1Nb2O6Ta73W19 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 57.4s
#   Diffusing element: Ta
#   Forward barrier: 13.031 eV
#   Backward barrier: 13.444 eV
#   Timing: relax=13.2s, neb=43.9s
#   Progress: 59/10000 (0.6%) | Completed: 59 | Failed: 0
#
# Composition 60/10000:
#
# Calculating Mo21Nb42O3Ta7W28 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 11.7s
#   Diffusing element: O
#   Forward barrier: 0.590 eV
#   Backward barrier: 0.617 eV
#   Timing: relax=5.5s, neb=6.0s
#   Progress: 60/10000 (0.6%) | Completed: 60 | Failed: 0
#
# Composition 61/10000:
#
# Calculating Mo1Nb19O33Ta20W26 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 75.3s
#   Diffusing element: Nb
#   Forward barrier: 28.878 eV
#   Backward barrier: 21.392 eV
#   Timing: relax=43.1s, neb=31.9s
#   Progress: 61/10000 (0.6%) | Completed: 61 | Failed: 0
#
# Composition 62/10000:
#
# Calculating Mo55Nb11O5Ta6W24 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 50.1s
#   Diffusing element: Mo
#   Forward barrier: 12.138 eV
#   Backward barrier: 11.857 eV
#   Timing: relax=14.8s, neb=35.0s
#   Progress: 62/10000 (0.6%) | Completed: 62 | Failed: 0
#
# Composition 63/10000:
#
# Calculating Mo10Nb1O31Ta0W57 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 91.1s
#   Diffusing element: W
#   Forward barrier: 115.016 eV
#   Backward barrier: 109.437 eV
#   Timing: relax=51.2s, neb=39.6s
#   Progress: 63/10000 (0.6%) | Completed: 63 | Failed: 0
#
# Composition 64/10000:
#
# Calculating Mo50Nb22O12Ta8W7 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 52.5s
#   Diffusing element: Mo
#   Forward barrier: 26.176 eV
#   Backward barrier: 21.943 eV
#   Timing: relax=18.4s, neb=33.8s
#   Progress: 64/10000 (0.6%) | Completed: 64 | Failed: 0
#
# Composition 65/10000:
#
# Calculating Mo12Nb19O47Ta16W5 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 86.7s
#   Diffusing element: O
#   Forward barrier: 28.564 eV
#   Backward barrier: 30.266 eV
#   Timing: relax=52.4s, neb=33.9s
#   Progress: 65/10000 (0.7%) | Completed: 65 | Failed: 0
#
# Composition 66/10000:
#
# Calculating Mo34Nb21O7Ta24W14 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 40.2s
#   Diffusing element: Ta
#   Forward barrier: 0.949 eV
#   Backward barrier: 1.101 eV
#   Timing: relax=19.4s, neb=20.4s
#   Progress: 66/10000 (0.7%) | Completed: 66 | Failed: 0
#
# Composition 67/10000:
#
# Calculating Mo22Nb69O2Ta1W6 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 48.7s
#   Diffusing element: Nb
#   Forward barrier: 50.611 eV
#   Backward barrier: 49.666 eV
#   Timing: relax=9.2s, neb=39.1s
#   Progress: 67/10000 (0.7%) | Completed: 67 | Failed: 0
#
# Composition 68/10000:
#
# Calculating Mo1Nb49O3Ta31W16 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 14.4s
#   Diffusing element: Nb
#   Forward barrier: 0.762 eV
#   Backward barrier: 0.565 eV
#   Timing: relax=7.0s, neb=7.1s
#   Progress: 68/10000 (0.7%) | Completed: 68 | Failed: 0
#
# Composition 69/10000:
#
# Calculating Mo26Nb25O20Ta7W22 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 75.5s
#   Diffusing element: W
#   Forward barrier: 57.162 eV
#   Backward barrier: 57.649 eV
#   Timing: relax=33.3s, neb=41.8s
#   Progress: 69/10000 (0.7%) | Completed: 69 | Failed: 0
#
# Composition 70/10000:
#
# Calculating Mo28Nb29O28Ta1W14 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 73.9s
#   Diffusing element: Mo
#   Forward barrier: 54.946 eV
#   Backward barrier: 51.553 eV
#   Timing: relax=35.4s, neb=38.1s
#   Progress: 70/10000 (0.7%) | Completed: 70 | Failed: 0
#
# Composition 71/10000:
#
# Calculating Mo18Nb49O2Ta27W4 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 46.0s
#   Diffusing element: Mo
#   Forward barrier: 21.174 eV
#   Backward barrier: 21.459 eV
#   Timing: relax=8.8s, neb=36.8s
#   Progress: 71/10000 (0.7%) | Completed: 71 | Failed: 0
#
# Composition 72/10000:
#
# Calculating Mo18Nb0O15Ta16W50 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 61.3s
#   Diffusing element: Mo
#   Forward barrier: 25.944 eV
#   Backward barrier: 24.147 eV
#   Timing: relax=27.5s, neb=33.3s
#   Progress: 72/10000 (0.7%) | Completed: 72 | Failed: 0
#
# Composition 73/10000:
#
# Calculating Mo9Nb18O49Ta11W14 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 86.7s
#   Diffusing element: Nb
#   Forward barrier: 71.794 eV
#   Backward barrier: 78.787 eV
#   Timing: relax=44.7s, neb=41.7s
#   Progress: 73/10000 (0.7%) | Completed: 73 | Failed: 0
#
# Composition 74/10000:
#
# Calculating Mo8Nb51O1Ta37W3 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 10.1s
#   Diffusing element: Ta
#   Forward barrier: 0.440 eV
#   Backward barrier: 0.519 eV
#   Timing: relax=4.8s, neb=4.9s
#   Progress: 74/10000 (0.7%) | Completed: 74 | Failed: 0
#
# Composition 75/10000:
#
# Calculating Mo7Nb1O5Ta7W79 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 31.2s
#   Diffusing element: W
#   Forward barrier: 2.302 eV
#   Backward barrier: 0.000 eV
#   Timing: relax=13.0s, neb=17.9s
#   Progress: 75/10000 (0.8%) | Completed: 75 | Failed: 0
#
# Composition 76/10000:
#
# Calculating Mo9Nb43O8Ta1W39 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 66.4s
#   Diffusing element: Nb
#   Forward barrier: 7.158 eV
#   Backward barrier: 8.021 eV
#   Timing: relax=21.3s, neb=44.7s
#   Progress: 76/10000 (0.8%) | Completed: 76 | Failed: 0
#
# Composition 77/10000:
#
# Calculating Mo2Nb21O23Ta17W37 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 74.0s
#   Diffusing element: W
#   Forward barrier: 103.237 eV
#   Backward barrier: 102.054 eV
#   Timing: relax=41.6s, neb=32.2s
#   Progress: 77/10000 (0.8%) | Completed: 77 | Failed: 0
#
# Composition 78/10000:
#
# Calculating Mo31Nb6O32Ta4W27 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 65.3s
#   Diffusing element: O
#   Forward barrier: 47.661 eV
#   Backward barrier: 51.782 eV
#   Timing: relax=31.2s, neb=33.8s
#   Progress: 78/10000 (0.8%) | Completed: 78 | Failed: 0
#
# Composition 79/10000:
#
# Calculating Mo62Nb7O6Ta6W20 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 29.1s
#   Diffusing element: Mo
#   Forward barrier: 0.915 eV
#   Backward barrier: 0.215 eV
#   Timing: relax=18.0s, neb=10.8s
#   Progress: 79/10000 (0.8%) | Completed: 79 | Failed: 0
#
# Composition 80/10000:
#
# Calculating Mo33Nb24O18Ta7W17 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 57.2s
#   Diffusing element: W
#   Forward barrier: 47.787 eV
#   Backward barrier: 53.011 eV
#   Timing: relax=20.4s, neb=36.4s
#   Progress: 80/10000 (0.8%) | Completed: 80 | Failed: 0
#
# Composition 81/10000:
#
# Calculating Mo2Nb44O7Ta13W33 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 43.0s
#   Diffusing element: Nb
#   Forward barrier: 55.520 eV
#   Backward barrier: 56.838 eV
#   Timing: relax=9.3s, neb=33.4s
#   Progress: 81/10000 (0.8%) | Completed: 81 | Failed: 0
#
# Composition 82/10000:
#
# Calculating Mo43Nb9O2Ta0W45 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 20.1s
#   Diffusing element: W
#   Forward barrier: 0.786 eV
#   Backward barrier: 0.657 eV
#   Timing: relax=10.2s, neb=9.6s
#   Progress: 82/10000 (0.8%) | Completed: 82 | Failed: 0
#
# Composition 83/10000:
#
# Calculating Mo5Nb36O12Ta37W10 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 59.8s
#   Diffusing element: Ta
#   Forward barrier: 16.096 eV
#   Backward barrier: 14.917 eV
#   Timing: relax=23.9s, neb=35.6s
#   Progress: 83/10000 (0.8%) | Completed: 83 | Failed: 0
#
# Composition 84/10000:
#
# Calculating Mo15Nb9O36Ta10W29 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 82.8s
#   Diffusing element: Ta
#   Forward barrier: 20.074 eV
#   Backward barrier: 17.134 eV
#   Timing: relax=52.4s, neb=30.1s
#   Progress: 84/10000 (0.8%) | Completed: 84 | Failed: 0
#
# Composition 85/10000:
#
# Calculating Mo40Nb39O1Ta2W17 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 54.5s
#   Diffusing element: Mo
#   Forward barrier: 12.150 eV
#   Backward barrier: 12.270 eV
#   Timing: relax=9.6s, neb=44.5s
#   Progress: 85/10000 (0.9%) | Completed: 85 | Failed: 0
#
# Composition 86/10000:
#
# Calculating Mo19Nb14O3Ta53W10 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 13.8s
#   Diffusing element: Ta
#   Forward barrier: 0.288 eV
#   Backward barrier: 0.646 eV
#   Timing: relax=7.4s, neb=6.2s
#   Progress: 86/10000 (0.9%) | Completed: 86 | Failed: 0
#
# Composition 87/10000:
#
# Calculating Mo6Nb52O3Ta35W4 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 32.6s
#   Diffusing element: Nb
#   Forward barrier: 0.408 eV
#   Backward barrier: 0.205 eV
#   Timing: relax=8.5s, neb=23.8s
#   Progress: 87/10000 (0.9%) | Completed: 87 | Failed: 0
#
# Composition 88/10000:
#
# Calculating Mo28Nb2O2Ta40W28 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 20.8s
#   Diffusing element: Mo
#   Forward barrier: 0.682 eV
#   Backward barrier: 0.861 eV
#   Timing: relax=13.5s, neb=6.9s
#   Progress: 88/10000 (0.9%) | Completed: 88 | Failed: 0
#
# Composition 89/10000:
#
# Calculating Mo1Nb62O24Ta7W7 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 82.5s
#   Diffusing element: O
#   Forward barrier: 100.142 eV
#   Backward barrier: 100.495 eV
#   Timing: relax=42.4s, neb=39.7s
#   Progress: 89/10000 (0.9%) | Completed: 89 | Failed: 0
#
# Composition 90/10000:
#
# Calculating Mo32Nb47O1Ta15W5 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 18.0s
#   Diffusing element: Mo
#   Forward barrier: 0.370 eV
#   Backward barrier: 0.560 eV
#   Timing: relax=7.7s, neb=9.9s
#   Progress: 90/10000 (0.9%) | Completed: 90 | Failed: 0
#
# Composition 91/10000:
#
# Calculating Mo28Nb15O2Ta10W44 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 20.4s
#   Diffusing element: Nb
#   Forward barrier: 0.261 eV
#   Backward barrier: 0.464 eV
#   Timing: relax=9.9s, neb=10.1s
#   Progress: 91/10000 (0.9%) | Completed: 91 | Failed: 0
#
# Composition 92/10000:
#
# Calculating Mo45Nb1O8Ta42W4 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 46.6s
#   Diffusing element: Mo
#   Forward barrier: 1.361 eV
#   Backward barrier: 0.124 eV
#   Timing: relax=15.1s, neb=31.1s
#   Progress: 92/10000 (0.9%) | Completed: 92 | Failed: 0
#
# Composition 93/10000:
#
# Calculating Mo2Nb16O49Ta20W13 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 82.6s
#   Diffusing element: Ta
#   Forward barrier: 26.328 eV
#   Backward barrier: 24.519 eV
#   Timing: relax=46.3s, neb=35.9s
#   Progress: 93/10000 (0.9%) | Completed: 93 | Failed: 0
#
# Composition 94/10000:
#
# Calculating Mo7Nb5O52Ta32W4 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 83.0s
#   Diffusing element: Ta
#   Forward barrier: 50.097 eV
#   Backward barrier: 56.929 eV
#   Timing: relax=40.8s, neb=41.9s
#   Progress: 94/10000 (0.9%) | Completed: 94 | Failed: 0
#
# Composition 95/10000:
#
# Calculating Mo0Nb54O11Ta1W34 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 53.4s
#   Diffusing element: W
#   Forward barrier: 25.367 eV
#   Backward barrier: 22.944 eV
#   Timing: relax=14.4s, neb=38.7s
#   Progress: 95/10000 (0.9%) | Completed: 95 | Failed: 0
#
# Composition 96/10000:
#
# Calculating Mo49Nb1O7Ta8W35 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 30.2s
#   Diffusing element: W
#   Forward barrier: 0.715 eV
#   Backward barrier: 1.144 eV
#   Timing: relax=15.5s, neb=14.4s
#   Progress: 96/10000 (1.0%) | Completed: 96 | Failed: 0
#
# Composition 97/10000:
#
# Calculating Mo21Nb26O19Ta13W21 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 73.1s
#   Diffusing element: Mo
#   Forward barrier: 12.842 eV
#   Backward barrier: 6.309 eV
#   Timing: relax=37.9s, neb=34.8s
#   Progress: 97/10000 (1.0%) | Completed: 97 | Failed: 0
#
# Composition 98/10000:
#
# Calculating Mo29Nb1O28Ta4W38 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 83.0s
#   Diffusing element: W
#   Forward barrier: 76.240 eV
#   Backward barrier: 83.493 eV
#   Timing: relax=48.7s, neb=33.9s
#   Progress: 98/10000 (1.0%) | Completed: 98 | Failed: 0
#
# Composition 99/10000:
#
# Calculating Mo22Nb35O23Ta12W8 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 61.1s
#   Diffusing element: O
#   Forward barrier: 109.756 eV
#   Backward barrier: 106.980 eV
#   Timing: relax=30.3s, neb=30.4s
#   Progress: 99/10000 (1.0%) | Completed: 99 | Failed: 0
#
# Composition 100/10000:
#
# Calculating Mo5Nb9O46Ta1W39 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 79.7s
#   Diffusing element: Nb
#   Forward barrier: 23.411 eV
#   Backward barrier: 9.406 eV
#   Timing: relax=49.3s, neb=30.1s
#   Progress: 100/10000 (1.0%) | Completed: 100 | Failed: 0
#
# Composition 101/10000:
#
# Calculating Mo23Nb15O22Ta7W33 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 72.3s
#   Diffusing element: Mo
#   Forward barrier: 25.301 eV
#   Backward barrier: 22.785 eV
#   Timing: relax=34.5s, neb=37.4s
#   Progress: 101/10000 (1.0%) | Completed: 101 | Failed: 0
#
# Composition 102/10000:
#
# Calculating Mo2Nb28O15Ta20W35 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 67.7s
#   Diffusing element: Nb
#   Forward barrier: 47.787 eV
#   Backward barrier: 38.919 eV
#   Timing: relax=29.8s, neb=37.6s
#   Progress: 102/10000 (1.0%) | Completed: 102 | Failed: 0
#
# Composition 103/10000:
#
# Calculating Mo15Nb9O1Ta43W32 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 12.9s
#   Diffusing element: W
#   Forward barrier: 0.904 eV
#   Backward barrier: 1.058 eV
#   Timing: relax=7.3s, neb=5.2s
#   Progress: 103/10000 (1.0%) | Completed: 103 | Failed: 0
#
# Composition 104/10000:
#
# Calculating Mo0Nb7O2Ta25W65 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 13.6s
#   Diffusing element: W
#   Forward barrier: 0.321 eV
#   Backward barrier: 0.761 eV
#   Timing: relax=7.1s, neb=6.2s
#   Progress: 104/10000 (1.0%) | Completed: 104 | Failed: 0
#
# Composition 105/10000:
#
# Calculating Mo11Nb6O21Ta41W22 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 77.9s
#   Diffusing element: Mo
#   Forward barrier: 112.662 eV
#   Backward barrier: 115.620 eV
#   Timing: relax=41.0s, neb=36.6s
#   Progress: 105/10000 (1.1%) | Completed: 105 | Failed: 0
#
# Composition 106/10000:
#
# Calculating Mo18Nb15O56Ta9W2 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 77.8s
#   Diffusing element: Ta
#   Forward barrier: 51.276 eV
#   Backward barrier: 50.549 eV
#   Timing: relax=44.1s, neb=33.4s
#   Progress: 106/10000 (1.1%) | Completed: 106 | Failed: 0
#
# Composition 107/10000:
#
# Calculating Mo9Nb46O8Ta32W5 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 44.9s
#   Diffusing element: Ta
#   Forward barrier: 0.529 eV
#   Backward barrier: 0.000 eV
#   Timing: relax=15.4s, neb=29.2s
#   Progress: 107/10000 (1.1%) | Completed: 107 | Failed: 0
#
# Composition 108/10000:
#
# Calculating Mo50Nb33O2Ta5W10 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 18.5s
#   Diffusing element: W
#   Forward barrier: 0.448 eV
#   Backward barrier: 0.702 eV
#   Timing: relax=6.3s, neb=11.9s
#   Progress: 108/10000 (1.1%) | Completed: 108 | Failed: 0
#
# Composition 109/10000:
#
# Calculating Mo49Nb15O15Ta4W18 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 85.1s
#   Diffusing element: Mo
#   Forward barrier: 56.199 eV
#   Backward barrier: 73.277 eV
#   Timing: relax=44.8s, neb=40.1s
#   Progress: 109/10000 (1.1%) | Completed: 109 | Failed: 0
#
# Composition 110/10000:
#
# Calculating Mo11Nb3O38Ta29W19 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 85.6s
#   Diffusing element: O
#   Forward barrier: 11.496 eV
#   Backward barrier: 17.282 eV
#   Timing: relax=51.0s, neb=34.3s
#   Progress: 110/10000 (1.1%) | Completed: 110 | Failed: 0
#
# Composition 111/10000:
#
# Calculating Mo12Nb30O33Ta13W13 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 79.8s
#   Diffusing element: W
#   Forward barrier: 158.245 eV
#   Backward barrier: 161.190 eV
#   Timing: relax=43.1s, neb=36.4s
#   Progress: 111/10000 (1.1%) | Completed: 111 | Failed: 0
#
# Composition 112/10000:
#
# Calculating Mo17Nb5O32Ta1W46 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 101.7s
#   Diffusing element: Mo
#   Forward barrier: 17.935 eV
#   Backward barrier: 24.840 eV
#   Timing: relax=63.3s, neb=38.1s
#   Progress: 112/10000 (1.1%) | Completed: 112 | Failed: 0
#
# Composition 113/10000:
#
# Calculating Mo59Nb12O21Ta7W1 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 76.4s
#   Diffusing element: O
#   Forward barrier: 95.294 eV
#   Backward barrier: 89.449 eV
#   Timing: relax=37.8s, neb=38.2s
#   Progress: 113/10000 (1.1%) | Completed: 113 | Failed: 0
#
# Composition 114/10000:
#
# Calculating Mo19Nb11O9Ta12W49 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 57.4s
#   Diffusing element: W
#   Forward barrier: 2.811 eV
#   Backward barrier: 3.387 eV
#   Timing: relax=16.6s, neb=40.4s
#   Progress: 114/10000 (1.1%) | Completed: 114 | Failed: 0
#
# Composition 115/10000:
#
# Calculating Mo13Nb27O35Ta9W17 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 92.7s
#   Diffusing element: Nb
#   Forward barrier: 25.258 eV
#   Backward barrier: 30.342 eV
#   Timing: relax=59.0s, neb=33.4s
#   Progress: 115/10000 (1.1%) | Completed: 115 | Failed: 0
#
# Composition 116/10000:
#
# ...
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 18.4s
#   Diffusing element: Ta
#   Forward barrier: 0.164 eV
#   Backward barrier: 0.220 eV
#   Timing: relax=11.9s, neb=6.2s
#   Progress: 1159/10000 (11.6%) | Completed: 1159 | Failed: 0
#
# Composition 1160/10000:
#
# Calculating Mo18Nb2O2Ta42W37 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 14.4s
#   Diffusing element: Mo
#   Forward barrier: 0.544 eV
#   Backward barrier: 0.589 eV
#   Timing: relax=7.3s, neb=7.9s
#   Progress: 1160/10000 (11.6%) | Completed: 1160 | Failed: 0
#
# Composition 1161/10000:
#
# Calculating Mo12Nb4O16Ta11W57 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 102.2s
#   Diffusing element: W
#   Forward barrier: 79.746 eV
#   Backward barrier: 77.244 eV
#   Timing: relax=60.0s, neb=41.9s
#   Progress: 1161/10000 (11.6%) | Completed: 1161 | Failed: 0
#
# Composition 1162/10000:
#
# Calculating Mo2Nb7O9Ta66W16 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 32.7s
#   Diffusing element: Ta
#   Forward barrier: 0.000 eV
#   Backward barrier: 0.899 eV
#   Timing: relax=14.6s, neb=17.7s
#   Progress: 1162/10000 (11.6%) | Completed: 1162 | Failed: 0
#
# Composition 1163/10000:
#
# Calculating Mo3Nb65O1Ta26W5 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 40.6s
#   Diffusing element: Nb
#   Forward barrier: 26.232 eV
#   Backward barrier: 26.285 eV
#   Timing: relax=9.1s, neb=31.0s
#   Progress: 1163/10000 (11.6%) | Completed: 1163 | Failed: 0
#
# Composition 1164/10000:
#
# Calculating Mo1Nb3O16Ta20W60 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 65.2s
#   Diffusing element: W
#   Forward barrier: 118.229 eV
#   Backward barrier: 124.898 eV
#   Timing: relax=33.7s, neb=31.3s
#   Progress: 1164/10000 (11.6%) | Completed: 1164 | Failed: 0
#
# Composition 1165/10000:
#
# Calculating Mo36Nb11O4Ta24W25 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 52.1s
#   Diffusing element: Mo
#   Forward barrier: 9.895 eV
#   Backward barrier: 10.900 eV
#   Timing: relax=13.7s, neb=38.1s
#   Progress: 1165/10000 (11.7%) | Completed: 1165 | Failed: 0
#
# Composition 1166/10000:
#
# Calculating Mo16Nb37O28Ta3W16 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 83.4s
#   Diffusing element: W
#   Forward barrier: 93.705 eV
#   Backward barrier: 92.774 eV
#   Timing: relax=46.4s, neb=36.7s
#   Progress: 1166/10000 (11.7%) | Completed: 1166 | Failed: 0
#
# Composition 1167/10000:
#
# Calculating Mo55Nb6O16Ta17W6 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 66.2s
#   Diffusing element: Mo
#   Forward barrier: 75.973 eV
#   Backward barrier: 88.515 eV
#   Timing: relax=34.0s, neb=31.9s
#   Progress: 1167/10000 (11.7%) | Completed: 1167 | Failed: 0
#
# Composition 1168/10000:
#
# Calculating Mo16Nb39O18Ta10W17 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 58.6s
#   Diffusing element: Mo
#   Forward barrier: 84.601 eV
#   Backward barrier: 88.745 eV
#   Timing: relax=25.1s, neb=33.1s
#   Progress: 1168/10000 (11.7%) | Completed: 1168 | Failed: 0
#
# Composition 1169/10000:
#
# Calculating Mo19Nb5O72Ta3W1 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 83.1s
#   Diffusing element: O
#   Forward barrier: 14.652 eV
#   Backward barrier: 14.541 eV
#   Timing: relax=51.7s, neb=31.1s
#   Progress: 1169/10000 (11.7%) | Completed: 1169 | Failed: 0
#
# Composition 1170/10000:
#
# Calculating Mo9Nb8O24Ta45W13 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 68.1s
#   Diffusing element: Ta
#   Forward barrier: 77.539 eV
#   Backward barrier: 76.422 eV
#   Timing: relax=34.4s, neb=33.4s
#   Progress: 1170/10000 (11.7%) | Completed: 1170 | Failed: 0
#
# Composition 1171/10000:
#
# Calculating Mo2Nb41O7Ta24W26 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 51.1s
#   Diffusing element: Ta
#   Forward barrier: 24.212 eV
#   Backward barrier: 24.772 eV
#   Timing: relax=9.2s, neb=41.5s
#   Progress: 1171/10000 (11.7%) | Completed: 1171 | Failed: 0
#
# Composition 1172/10000:
#
# Calculating Mo57Nb6O35Ta0W1 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 86.6s
#   Diffusing element: Mo
#   Forward barrier: 40.167 eV
#   Backward barrier: 44.748 eV
#   Timing: relax=52.3s, neb=33.9s
#   Progress: 1172/10000 (11.7%) | Completed: 1172 | Failed: 0
#
# Composition 1173/10000:
#
# Calculating Mo19Nb23O40Ta0W17 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 108.0s
#   Diffusing element: O
#   Forward barrier: 9.282 eV
#   Backward barrier: 2.680 eV
#   Timing: relax=66.1s, neb=41.6s
#   Progress: 1173/10000 (11.7%) | Completed: 1173 | Failed: 0
#
# Composition 1174/10000:
#
# Calculating Mo12Nb28O19Ta6W35 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 70.9s
#   Diffusing element: W
#   Forward barrier: 95.169 eV
#   Backward barrier: 96.743 eV
#   Timing: relax=37.2s, neb=33.3s
#   Progress: 1174/10000 (11.7%) | Completed: 1174 | Failed: 0
#
# Composition 1175/10000:
#
# Calculating Mo6Nb7O14Ta26W47 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 77.0s
#   Diffusing element: Ta
#   Forward barrier: 36.638 eV
#   Backward barrier: 26.681 eV
#   Timing: relax=42.6s, neb=34.1s
#   Progress: 1175/10000 (11.8%) | Completed: 1175 | Failed: 0
#
# Composition 1176/10000:
#
# Calculating Mo6Nb43O14Ta24W13 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 63.0s
#   Diffusing element: Nb
#   Forward barrier: 31.740 eV
#   Backward barrier: 28.013 eV
#   Timing: relax=26.3s, neb=36.4s
#   Progress: 1176/10000 (11.8%) | Completed: 1176 | Failed: 0
#
# Composition 1177/10000:
#
# Calculating Mo3Nb13O8Ta6W70 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 57.0s
#   Diffusing element: Ta
#   Forward barrier: 4.921 eV
#   Backward barrier: 4.538 eV
#   Timing: relax=20.3s, neb=36.3s
#   Progress: 1177/10000 (11.8%) | Completed: 1177 | Failed: 0
#
# Composition 1178/10000:
#
# Calculating Mo11Nb13O10Ta40W26 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 58.8s
#   Diffusing element: Ta
#   Forward barrier: 59.616 eV
#   Backward barrier: 62.993 eV
#   Timing: relax=22.7s, neb=35.8s
#   Progress: 1178/10000 (11.8%) | Completed: 1178 | Failed: 0
#
# Composition 1179/10000:
#
# Calculating Mo35Nb24O17Ta18W6 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 80.6s
#   Diffusing element: Mo
#   Forward barrier: 80.814 eV
#   Backward barrier: 77.955 eV
#   Timing: relax=44.8s, neb=35.6s
#   Progress: 1179/10000 (11.8%) | Completed: 1179 | Failed: 0
#
# Composition 1180/10000:
#
# Calculating Mo4Nb35O11Ta6W44 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 73.9s
#   Diffusing element: Ta
#   Forward barrier: 35.711 eV
#   Backward barrier: 38.864 eV
#   Timing: relax=36.5s, neb=37.1s
#   Progress: 1180/10000 (11.8%) | Completed: 1180 | Failed: 0
#
# Composition 1181/10000:
#
# Calculating Mo40Nb31O4Ta6W19 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 35.7s
#   Diffusing element: Nb
#   Forward barrier: 0.000 eV
#   Backward barrier: 0.275 eV
#   Timing: relax=12.2s, neb=23.2s
#   Progress: 1181/10000 (11.8%) | Completed: 1181 | Failed: 0
#
# Composition 1182/10000:
#
# Calculating Mo28Nb17O5Ta43W7 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 49.8s
#   Diffusing element: Nb
#   Forward barrier: 8.561 eV
#   Backward barrier: 8.174 eV
#   Timing: relax=14.8s, neb=34.7s
#   Progress: 1182/10000 (11.8%) | Completed: 1182 | Failed: 0
#
# Composition 1183/10000:
#
# Calculating Mo9Nb46O13Ta22W10 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 52.3s
#   Diffusing element: O
#   Forward barrier: 12.662 eV
#   Backward barrier: 10.258 eV
#   Timing: relax=18.8s, neb=33.1s
#   Progress: 1183/10000 (11.8%) | Completed: 1183 | Failed: 0
#
# Composition 1184/10000:
#
# Calculating Mo1Nb63O13Ta17W5 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 47.6s
#   Diffusing element: Nb
#   Forward barrier: 70.708 eV
#   Backward barrier: 70.645 eV
#   Timing: relax=15.6s, neb=31.7s
#   Progress: 1184/10000 (11.8%) | Completed: 1184 | Failed: 0
#
# Composition 1185/10000:
#
# Calculating Mo2Nb67O6Ta4W21 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 12.1s
#   Diffusing element: Nb
#   Forward barrier: 0.485 eV
#   Backward barrier: 0.097 eV
#   Timing: relax=7.1s, neb=4.7s
#   Progress: 1185/10000 (11.8%) | Completed: 1185 | Failed: 0
#
# Composition 1186/10000:
#
# Calculating Mo18Nb21O32Ta16W13 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 79.0s
#   Diffusing element: O
#   Forward barrier: 47.395 eV
#   Backward barrier: 51.345 eV
#   Timing: relax=44.5s, neb=34.2s
#   Progress: 1186/10000 (11.9%) | Completed: 1186 | Failed: 0
#
# Composition 1187/10000:
#
# Calculating Mo1Nb7O9Ta5W78 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 57.8s
#   Diffusing element: O
#   Forward barrier: 26.756 eV
#   Backward barrier: 27.825 eV
#   Timing: relax=23.2s, neb=34.3s
#   Progress: 1187/10000 (11.9%) | Completed: 1187 | Failed: 0
#
# Composition 1188/10000:
#
# Calculating Mo40Nb35O10Ta7W8 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 48.4s
#   Diffusing element: Nb
#   Forward barrier: 28.042 eV
#   Backward barrier: 30.724 eV
#   Timing: relax=15.2s, neb=32.9s
#   Progress: 1188/10000 (11.9%) | Completed: 1188 | Failed: 0
#
# Composition 1189/10000:
#
# Calculating Mo8Nb4O53Ta0W34 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 63.6s
#   Diffusing element: W
#   Forward barrier: 44.638 eV
#   Backward barrier: 58.622 eV
#   Timing: relax=32.7s, neb=30.6s
#   Progress: 1189/10000 (11.9%) | Completed: 1189 | Failed: 0
#
# Composition 1190/10000:
#
# Calculating Mo11Nb11O47Ta0W31 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 97.1s
#   Diffusing element: O
#   Forward barrier: 64.275 eV
#   Backward barrier: 69.281 eV
#   Timing: relax=61.3s, neb=35.4s
#   Progress: 1190/10000 (11.9%) | Completed: 1190 | Failed: 0
#
# Composition 1191/10000:
#
# Calculating Mo5Nb6O2Ta54W33 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 14.4s
#   Diffusing element: W
#   Forward barrier: 0.619 eV
#   Backward barrier: 0.083 eV
#   Timing: relax=6.8s, neb=7.4s
#   Progress: 1191/10000 (11.9%) | Completed: 1191 | Failed: 0
#
# Composition 1192/10000:
#
# Calculating Mo20Nb7O34Ta9W30 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 82.4s
#   Diffusing element: W
#   Forward barrier: 71.637 eV
#   Backward barrier: 73.250 eV
#   Timing: relax=48.3s, neb=33.8s
#   Progress: 1192/10000 (11.9%) | Completed: 1192 | Failed: 0
#
# Composition 1193/10000:
#
# Calculating Mo8Nb48O11Ta9W24 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 65.3s
#   Diffusing element: Ta
#   Forward barrier: 30.685 eV
#   Backward barrier: 26.384 eV
#   Timing: relax=22.6s, neb=42.2s
#   Progress: 1193/10000 (11.9%) | Completed: 1193 | Failed: 0
#
# Composition 1194/10000:
#
# Calculating Mo25Nb26O19Ta1W30 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 64.8s
#   Diffusing element: Nb
#   Forward barrier: 98.242 eV
#   Backward barrier: 86.766 eV
#   Timing: relax=31.5s, neb=33.0s
#   Progress: 1194/10000 (11.9%) | Completed: 1194 | Failed: 0
#
# Composition 1195/10000:
#
# Calculating Mo28Nb4O6Ta29W33 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 52.1s
#   Diffusing element: W
#   Forward barrier: 0.890 eV
#   Backward barrier: 0.000 eV
#   Timing: relax=17.8s, neb=33.9s
#   Progress: 1195/10000 (11.9%) | Completed: 1195 | Failed: 0
#
# Composition 1196/10000:
#
# Calculating Mo62Nb1O18Ta3W16 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 63.5s
#   Diffusing element: Mo
#   Forward barrier: 29.181 eV
#   Backward barrier: 27.771 eV
#   Timing: relax=28.0s, neb=35.2s
#   Progress: 1196/10000 (12.0%) | Completed: 1196 | Failed: 0
#
# Composition 1197/10000:
#
# Calculating Mo23Nb0O3Ta72W1 (run 1)... CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda
# ✓ Completed in 15.1s
#   Diffusing element: Mo
#   Forward barrier: 0.485 eV
#   Backward barrier: 0.411 eV
#   Timing: relax=6.1s, neb=8.7s
#   Progress: 1197/10000 (12.0%) | Completed: 1197 | Failed: 0
#
# Composition 1198/10000:
#
# Calculating Mo0Nb13O27Ta42W17 (run 1)...
